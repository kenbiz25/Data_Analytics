# %% [markdown]
# <a href="https://colab.research.google.com/github/kenbiz25/Data_Analytics/blob/main/twitterpull.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/tweepy/tweepy.git
# Out:
# ...
#   Cloning https://github.com/tweepy/tweepy.git to /tmp/pip-req-build-pen4tegs
#   Running command git clone --filter=blob:none --quiet https://github.com/tweepy/tweepy.git /tmp/pip-req-build-pen4tegs
#   Resolved https://github.com/tweepy/tweepy.git to commit db28c0e84826485755eb7fcef0c30f75395dff5f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import tweepy
import pandas as pd

# Use Twitter API v2 Bearer Token (not Consumer/Access Keys)
BEARER_TOKEN = "token_here"

# Authenticate with Tweepy v2
client = tweepy.Client(bearer_token=BEARER_TOKEN)

search_query = "hiring SEO Specialist -is:retweet -is:reply -has:links"
no_of_tweets = 10

try:
    # Fetch tweets
    tweets = client.search_recent_tweets(query=search_query, max_results=no_of_tweets, tweet_fields=["created_at", "public_metrics", "source"], user_fields=["name"], expansions="author_id")

    # Extract user data
    users = {u["id"]: u["name"] for u in tweets.includes["users"]}

    # Convert tweets to DataFrame
    attributes_container = [[users[tweet.author_id], tweet.created_at, tweet.public_metrics["like_count"], tweet.source, tweet.text] for tweet in tweets.data]

    # Column names
    columns = ["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"]

    # Create DataFrame
    tweets_df = pd.DataFrame(attributes_container, columns=columns)

    print(tweets_df)
except Exception as e:
    print("Status Failed On,", str(e))
# Out:
#             User              Date Created  Number of Likes Source of Tweet  \
# 0        Adetola 2025-03-21 17:19:22+00:00                4            None
# 1    Segment SEO 2025-03-21 16:46:52+00:00                1            None
# 2  Software Jobs 2025-03-17 18:10:53+00:00                1            None
#
#                                                Tweet
# 0  Hiring SEO Specialist, reply if you are intere...
# 1  Hiring Alert - We are hiring an #SEO Specialis...
# 2  📢 Hiring in Jaipur!\n\n1️⃣ WordPress Developer...

# %%
tweets_df
# Out:
#             User              Date Created  Number of Likes Source of Tweet  \
# 0        Adetola 2025-03-21 17:19:22+00:00                4            None
# 1    Segment SEO 2025-03-21 16:46:52+00:00                1            None
# 2  Software Jobs 2025-03-17 18:10:53+00:00                1            None
#
#                                                Tweet
# 0  Hiring SEO Specialist, reply if you are intere...
# 1  Hiring Alert - We are hiring an #SEO Specialis...
# 2  📢 Hiring in Jaipur!\n\n1️⃣ WordPress Developer...

# %%
from google.colab import files
tweets_df.to_csv('tweets.csv')
files.download('tweets.csv')
